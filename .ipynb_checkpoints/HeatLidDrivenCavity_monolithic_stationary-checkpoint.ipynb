# %% [markdown]
# # Solving incompressible heat flow in a cavity

# %% [markdown]
# Let us consider the Stokes equations for the velocity $\mathbf{u}$ and the pressure $p$ of an incompressible fluid
#
# \begin{align*}
#     \nabla \cdot \mathbf{u} &= 0,  \\
#      \left( \mathbf{u}\cdot\nabla \right)\mathbf{u} + \nabla p - 2\mu \nabla \cdot \mathbf{D}(\mathbf{u}) &= 0,
# \end{align*}
#
# where  $\mathbf{D}(\mathbf{u}) = \mathrm{sym}(\mathbf{u}) = \frac{1}{2}\left(\nabla \mathbf{u} +  \left( \nabla \mathbf{u} \right)^{\mathrm{T}} \right)$ is the Newtonian fluid's rate of strain tensor and $\mu$ is the viscosity.
#
# Moreover, consider a convection-diffusion equation that governs the evolution of the temperature field
# \begin{align*}
#     \mathbf{u}\cdot\nabla T - \kappa \Delta T &= 0,
# \end{align*}
# where $\kappa$ is the constant thermal condictivity.
#
# The domain is $\Omega = [0,L] \times [0,1]$, with $L > 0$, and the space variable is $\mathbf{x}= \begin{pmatrix} x_0 \\ x_1 \end{pmatrix}$.
#
# Boundary conditions for the velocity are
#
# \begin{align*}
#     \mathbf{u}(x_0,1) &= \begin{pmatrix} 1 \\ 0 \end{pmatrix}, &&  0 \leq x_0 \leq L \\
#     \mathbf{u}(x_0,x_1) &= \begin{pmatrix} 0 \\ 0 \end{pmatrix} && \text{elsewhere on } \partial \Omega,
# \end{align*}
#
# and for the temperature field we set
#
# \begin{align*}
#     T(0,x_1) &= T_h, && 0 \leq x_1 \leq 1, \\
#     T(L,x_1) &= T_c, && 0 \leq x_1 \leq 1. \\
# \end{align*}

# %% [markdown]
# ## Python packages

# %% [markdown]
# Import the Python packages for use in this notebook.

# %% [markdown]
# We need the finite element method library FEniCS.

# %%
import fenics

# %%
import dolfin
dolfin.__version__
# Out:
# '2019.1.0'

# %%
import ufl
ufl.__version__
# Out:
# '2019.1.0'

# %%
import pymor
pymor.__version__
# Out:
# '2021.1.0'

# %% [markdown]
# FEniCS has convenient plotting features that don't require us to import `matplotlib`; but using `matplotlib` directly will allow us to annotate the plots.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Benchmark parameters

# %% [markdown]
# Set constant Reynolds number and conductivity coefficient Kappa. For each we define a `fenics.Constant` for use in the variational form so that FEniCS can more efficiently compile the finite element code.

# %%
#dynamic_viscosity = 10.
Re = fenics.Constant(500)
#mu = fenics.Constant(dynamic_viscosity)
prandtl_number = 0.71
#Pr = fenics.Constant(prandtl_number)
kappa = fenics.Constant(1./0.71)

# %% [markdown]
# Furthermore the benchmark problem involves hot and cold walls with constant temperatures $T_h$ and $T_c$, respectively.

# %%
hot_wall_temperature = 0.5
T_h = fenics.Constant(hot_wall_temperature)
cold_wall_temperature = -0.5
T_c = fenics.Constant(cold_wall_temperature)

# %% [markdown]
# ## Structured mesh definition
# Now, define a structured mesh on the rectangle with bottom left corner $(0,0)$ and top right corner $(\bar{x},\bar{y}) = (L,1)$ and ratio $(\bar{x} - 0)/(\bar{y} - 0) = L$.

# %%
L = 1.2

# %%
if 0:
    N = 8
    mesh = fenics.UnitSquareMesh(N, N)
    ratio = 1.0
elif 1:
    ny = 10
    nx = int(ny*L)#1.0/ratio)
    mesh = fenics.RectangleMesh(fenics.Point(0, 0), 
                                fenics.Point(L, 1.0), nx, ny, "right/left")
else: 
    #unstructured mesh, mshr module needed
    domain = mshr.Rectangle(fenics.Point(0, 0), fenics.Point(L,1.0))
    mesh = mshr.generate_mesh(domain, 8)

# %%
fenics.plot(mesh)
plt.title("Mesh")
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.show()

# %%
hy = 1./ny
hy
# Out:
# 0.1

# %% [markdown]
# ## Mixed finite element function space, test functions, and solution functions

# %% [markdown]
# Make the mixed finite element. We choose pressure and velocity subspaces analagous to the Taylor-Hood (i.e. P2P1) mixed element [1], but we extend this further with a P1 element for the temperature.

# %%
P1 = fenics.FiniteElement('P', mesh.ufl_cell(), 1)
P2 = fenics.VectorElement('P', mesh.ufl_cell(), 2)

#P2 = fenics.VectorFunctionSpace(mesh, 'P', 2)
#P1 = fenics.FunctionSpace(mesh, 'P', 1)

mixed_element = fenics.MixedElement([P1, P2,P1])

# %% [markdown]
# |Note|
# |----|
# |`fenics.FiniteElement` requires the `mesh.ufl_cell()` argument to determine some aspects of the domain (e.g. that the spatial domain is two-dimensional).|

# %% [markdown]
# Make the mixed finite element function space $\mathbf{W}$, which enumerates the mixed element basis functions for pressure, velocity and temperature on each cell of the mesh.

# %%
W = fenics.FunctionSpace(mesh, mixed_element)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.

# %% [markdown]
# Make the test functions $\psi_p,\boldsymbol{\psi}_u, \psi_T \in \mathbf{W}$.

# %%
# TestFunctions
psi_p, psi_u, psi_T = fenics.TestFunctions(W)

# %%
type(psi_p), type(psi_u), type(psi_T)
# Out:
# (ufl.indexed.Indexed, ufl.tensors.ListTensor, ufl.indexed.Indexed)

# %% [markdown]
# Make the Heat-Navier-Stokes system solution function $\mathbf{w} \in \mathbf{W}$ and obtain references to its components $p$, $\mathbf{u}, T$.

# %%
#solution functions
w = fenics.Function(W)
p, u, T = fenics.split(w)

#test functions
w_n = fenics.Function(W)
p_n, u_n, T_n = fenics.split(w_n)

# %% [markdown]
# ## Nonlinear variational form

# %% [markdown]
# Multiply equations by suitable test funcions $\psi_p, \boldsymbol{\psi}_u, \psi_T$ and integrate over the domain. We obtain
#
# \begin{align*}
#     ({\psi}_p, \nabla \cdot \mathbf{u}) &= 0  \\
#     \left( \boldsymbol{\psi}_u,  ( \mathbf{u}\cdot\nabla) \mathbf{u} \right) -(p, \nabla \cdot \boldsymbol{\psi}_u) + \mu (\nabla \mathbf{u}, \nabla \boldsymbol{\psi}_u)  &=0,
# \end{align*}
# where
# \begin{align*}
# b( \mathbf{u},\mathbf{v},\boldsymbol{\psi}_u) &= \left( ( \mathbf{u}\cdot\nabla) \mathbf{v}, \boldsymbol{\psi}_u \right),
# \end{align*}
# and
# \begin{align*}
#     - (\mathbf{u}\cdot\nabla \psi_T, T) + \kappa(\nabla T, \nabla \psi_T) &= 0.
# \end{align*}
#
# We can write the nonlinear system of equations as
#
# \begin{equation*}
# \mathbf{F}(\mathbf{w}) = \mathbf{0}.
# \end{equation*}

# %%
inner, dot, grad, div, sym = \
    fenics.inner, fenics.dot, fenics.grad, fenics.div, fenics.sym
    
mass = -psi_p*div(u)

momentum = dot(psi_u, dot(grad(u), u)) - div(psi_u)*p \
    + 2.*(1./Re)*inner(sym(grad(psi_u)), sym(grad(u)))

energy = dot(grad(psi_T), kappa*grad(T) - T*u)

F = (mass + momentum + energy )*fenics.dx

# %% [markdown]
# ## Boundary conditions

# %% [markdown]
# We need boundary conditions before we can define a nonlinear variational *problem* (i.e. in this case a boundary value problem).
# For the velocity, we consider the moving top lid
# \begin{align*}
#     \mathbf{u}(1,x_1) &=
#     \begin{pmatrix} 1 \\ 0 \end{pmatrix}, 0 \leq x_1 \leq L.
# \end{align*}
# We physically consider *no slip* velocity boundary conditions for the orther boundaries. These manifest as homogeneous Dirichlet boundary conditions. For the temperature boundary conditions, we consider a constant hot temperature on the left wall, a constant cold temperature on the right wall, and adiabatic (i.e. zero heat transfer) conditions on the top and bottom walls. Because the problem's geometry is simple, we can identify the boundaries with the following piece-wise function.
#
# \begin{align*}
#     T(\mathbf{x}) &=
#     \begin{cases}
#         T_h , && x_0 = 0, \\
#         T_c , && x_0 = L.
#     \end{cases}
# \end{align*}

# %%
hot_wall = "near(x[0],  0.)" #x=0 

cold_wall = "near(x[0],"+str(L)+")" #x= \bar{x}

top_wall = "near(x[1],  1.)" #y=1

bottom_wall = "near(x[1],  0.)" #y=0

walls = hot_wall + " | " + cold_wall + " | " + bottom_wall

# %%
pressure_point = "near(x[0],  0.) & (x[1]<= "+str(hy)+")" #& near(x[1],  0.)

# %% [markdown]
# Define the boundary conditions on the appropriate subspaces.

# %%
W_p = W.sub(0)
# set velocity BC
boundary_conditions = [fenics.DirichletBC(W_p, 0. , pressure_point)]

# %%
# numbering starts at 0 -> W.sub(0) = W_p
W_u = W.sub(1)
# set velocity BC
boundary_conditions.extend([fenics.DirichletBC(W_u, (0., 0.), walls), 
                       fenics.DirichletBC(W_u, (1., 0.), top_wall)])

# %%
# set temperature BC

W_T = W.sub(2)
# set velocity BC
boundary_conditions.extend([fenics.DirichletBC(W_T, hot_wall_temperature, hot_wall), 
                             fenics.DirichletBC(W_T, cold_wall_temperature, cold_wall)])

# %%
boundary_conditions
# Out:
# [<dolfin.fem.dirichletbc.DirichletBC at 0x7fa1dc435c70>,
#  <dolfin.fem.dirichletbc.DirichletBC at 0x7fa1e260c770>,
#  <dolfin.fem.dirichletbc.DirichletBC at 0x7fa1dc461180>,
#  <dolfin.fem.dirichletbc.DirichletBC at 0x7fa1dc484b30>,
#  <dolfin.fem.dirichletbc.DirichletBC at 0x7fa1dc473b80>]

# %% [markdown]
# ## Nonlinear variational problem

# %% [markdown]
# Now we have everything we need to solve the variational problem.

# %%
#set compiler
from dolfin.cpp.parameter import parameters, Parameters
from dolfin.parameter import ffc_default_parameters

if not parameters.has_parameter_set("form_compiler"):
    parameters.add(ffc_default_parameters())

# %%
# solve the system for velocity and pressure
fenics.solve(F == 0, w, boundary_conditions)
# Out:
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.373e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 2.807e-02 (tol = 1.000e-10) r (rel) = 2.045e-03 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 1.220e-02 (tol = 1.000e-10) r (rel) = 8.885e-04 (tol = 1.000e-09)
#   Newton iteration 3: r (abs) = 1.036e-02 (tol = 1.000e-10) r (rel) = 7.550e-04 (tol = 1.000e-09)
#   Newton iteration 4: r (abs) = 5.164e-03 (tol = 1.000e-10) r (rel) = 3.762e-04 (tol = 1.000e-09)
#   Newton iteration 5: r (abs) = 3.739e-03 (tol = 1.000e-10) r (rel) = 2.724e-04 (tol = 1.000e-09)
#   Newton iteration 6: r (abs) = 2.356e-04 (tol = 1.000e-10) r (rel) = 1.716e-05 (tol = 1.000e-09)
#   Newton iteration 7: r (abs) = 2.814e-06 (tol = 1.000e-10) r (rel) = 2.050e-07 (tol = 1.000e-09)
#   Newton iteration 8: r (abs) = 5.479e-10 (tol = 1.000e-10) r (rel) = 3.992e-11 (tol = 1.000e-09)
#   Newton solver finished in 8 iterations and 8 linear solver iterations.

# %%
dir(F)
F.coefficients()
# Out:
# (Coefficient(FunctionSpace(None, FiniteElement('Real', None, 0)), 0),
#  Coefficient(FunctionSpace(None, FiniteElement('Real', None, 0)), 1),
#  Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 4), MixedElement(FiniteElement('Lagrange', triangle, 1), VectorElement(FiniteElement('Lagrange', triangle, 2), dim=2), FiniteElement('Lagrange', triangle, 1))), 9))

# %% [markdown]
# |Note|
# |----|
# |`solver.solve` will modify the solution `w`, which means that `u` and `p` will also be modified.|

# %% [markdown]
# Now plot the velocity field, and pressure and temperature.

# %%
def plot_w(w, split = False):
    
    if split:
        p, u, T = fenics.split(w.leaf_node())
    else:
        p, u, T  = w.split()   
    
    fig = fenics.plot(u)
    plt.title("Velocity vector field")
    plt.xlabel("$x$")
    plt.ylabel("$y$")    
    plt.colorbar(fig)  
    plt.show()

    
    fig = fenics.plot(p)
    plt.title("Pressure field")
    plt.xlabel("$x$")
    plt.ylabel("$y$")    
    plt.colorbar(fig)    
    plt.show()
    
    fig = fenics.plot(T)
    plt.title("Temperature field")
    plt.xlabel("$x$")
    plt.ylabel("$y$")    
    plt.colorbar(fig)    
    plt.show()
    
    return

# %%
def solve_fom_fenics(mu=1.):
    Re.assign(mu)
    fenics.solve(F == 0, w, boundary_conditions)
    return w

# %%
w = solve_fom_fenics(mu=5.)
# Out:
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.098e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 7.013e-03 (tol = 1.000e-10) r (rel) = 7.709e-03 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 2.488e-06 (tol = 1.000e-10) r (rel) = 2.735e-06 (tol = 1.000e-09)
#   Newton iteration 3: r (abs) = 1.021e-13 (tol = 1.000e-10) r (rel) = 1.122e-13 (tol = 1.000e-09)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.

# %%
plot_w(w)

# %%
w_l = fenics.Function(W)
w = solve_fom_fenics(mu=5.)
w_l.leaf_node().vector()[:] = w.leaf_node().vector()[:]
plot_w(w_l)
# Out:
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.021e-13 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.

# %%
w_h = fenics.Function(W)
w = solve_fom_fenics(mu=500.)
w_h.leaf_node().vector()[:] = w.leaf_node().vector()[:]
plot_w(w_h)
# Out:
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.235e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 1.169e-02 (tol = 1.000e-10) r (rel) = 2.762e-02 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 9.869e-03 (tol = 1.000e-10) r (rel) = 2.331e-02 (tol = 1.000e-09)
#   Newton iteration 3: r (abs) = 3.457e-03 (tol = 1.000e-10) r (rel) = 8.163e-03 (tol = 1.000e-09)
#   Newton iteration 4: r (abs) = 2.510e-03 (tol = 1.000e-10) r (rel) = 5.926e-03 (tol = 1.000e-09)
#   Newton iteration 5: r (abs) = 1.110e-04 (tol = 1.000e-10) r (rel) = 2.621e-04 (tol = 1.000e-09)
#   Newton iteration 6: r (abs) = 6.437e-07 (tol = 1.000e-10) r (rel) = 1.520e-06 (tol = 1.000e-09)
#   Newton iteration 7: r (abs) = 4.306e-11 (tol = 1.000e-10) r (rel) = 1.017e-10 (tol = 1.000e-09)
#   Newton solver finished in 7 iterations and 7 linear solver iterations.

# %%
diff = fenics.Function(W)
diff.leaf_node().vector()[:] = w_h.leaf_node().vector()[:] - w_l.leaf_node().vector()[:]
plot_w(diff)

# %% [markdown]
# # ROM with Pymor
#
# ## Target parameters
#
# $L, Re, T_c, T_h, \kappa$

# %%
# ### pyMOR wrapping
from pymor.bindings.fenics import FenicsVectorSpace, FenicsOperator, FenicsVisualizer
from pymor.models.basic import StationaryModel
from pymor.operators.constructions import VectorOperator

# %%
space = FenicsVectorSpace(W)

# %%
from pymor.tools.formatsrc import print_source

# %%
from pymor.basic import *

# %%
op = FenicsOperator(F, space, space, w, boundary_conditions,
                    parameter_setter=lambda mu: Re.assign(mu['Re'].item()),
                    parameters={'Re':1},
                    #parameters={'T_i': 1,'T_c': 1,'T_h':1,'kappa':1,'Re':1},
                    solver_options={'inverse': 
                                    {'type': 'newton', 'rtol': 1e-6, 'maxiter':500,
                                    'error_measure': 'residual'}})

# %%
rhs = VectorOperator(op.range.zeros())

# %%
fom = StationaryModel(op, rhs,
                     visualizer=FenicsVisualizer(space))

# %%
def solve_fom_pymor(Re=1., rtol=1e-6, return_residuals=True):
    mu = fom.parameters.parse([Re])
    UU, data = newton(fom.operator, fom.rhs.as_vector(), 
                     mu=mu, rtol=rtol, return_residuals=return_residuals, 
                     error_measure='residual')
    # fom solution
    U_fe = fenics.Function(W)
    U_fe.leaf_node().vector()[:] = UU.to_numpy().squeeze()#.reshape((UU.to_numpy().size,))
    
    return U_fe

# %% [markdown]
# (n,1) -> (n,)

# %%
reynolds = 500.
U_py = solve_fom_pymor(Re=reynolds) # fom pymor
w = solve_fom_fenics(mu=reynolds) #fom fenics
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# 01:34 newton:      norm:0.000e+00                                 res:5.523e+00
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# 01:36 newton: it:1 norm:8.067e+00 upd:8.067e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 01:36 newton: it:2 norm:7.101e+00 upd:3.875e+00 rel_upd:5.457e-01 res:1.220e-02 red:4.345e-01 tot_red:2.208e-03
# 01:37 newton: it:3 norm:7.919e+00 upd:3.823e+00 rel_upd:4.827e-01 res:1.036e-02 red:8.498e-01 tot_red:1.877e-03
# 01:38 newton: it:4 norm:7.766e+00 upd:2.234e+00 rel_upd:2.877e-01 res:5.164e-03 red:4.983e-01 tot_red:9.351e-04
# 01:38 newton: it:5 norm:8.246e+00 upd:1.893e+00 rel_upd:2.296e-01 res:3.739e-03 red:7.240e-01 tot_red:6.770e-04
# 01:39 newton: it:6 norm:8.094e+00 upd:4.220e-01 rel_upd:5.214e-02 res:2.356e-04 red:6.300e-02 tot_red:4.265e-05
# 01:40 newton: it:7 norm:8.099e+00 upd:3.260e-02 rel_upd:4.026e-03 res:2.814e-06 red:1.194e-02 tot_red:5.095e-07
# 01:40 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.814e-06 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 5.479e-10 (tol = 1.000e-10) r (rel) = 1.947e-04 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 6.805e-16 (tol = 1.000e-10) r (rel) = 2.418e-10 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.

# %%
# fom solution
plot_w(U_py)

# %%
#plot error
plt.semilogy(np.absolute( w.leaf_node().vector()[:]-U_py.leaf_node().vector()[:] ),'*')

# %%
diff = fenics.Function(W)
diff.leaf_node().vector()[:] = U_py.leaf_node().vector()[:] - w.leaf_node().vector()[:]
plot_w(diff)

# %%
parameter_space = fom.parameters.space((1, 500.))

# ### ROM generation (POD/DEIM)
from pymor.algorithms.ei import ei_greedy
from pymor.algorithms.newton import newton
from pymor.algorithms.pod import pod
from pymor.operators.ei import EmpiricalInterpolatedOperator
from pymor.reductors.basic import StationaryRBReductor

# %%
# collect snapshots

U = fom.solution_space.empty()
residuals = fom.solution_space.empty()

for mu_val in parameter_space.sample_randomly(10):#mu_list:
    #UU = fom.solve(mu)
    UU, data = newton(fom.operator, fom.rhs.as_vector(), 
                      mu=mu_val, #fom.parameters.parse([mu_val]), 
                      rtol=1e-6, return_residuals=True, 
                      maxiter=500,
                      error_measure='residual')
    U.append(UU)
    residuals.append(data['residuals'])
    # U_fe = fenics.Function(W)
    # U_fe.leaf_node().vector()[:] = UU.to_numpy().reshape((UU.to_numpy().size,))
    # plot_w(U_fe)
# Out:
# 01:58 newton:      norm:0.000e+00                                 res:5.523e+00
# 01:59 newton: it:1 norm:8.081e+00 upd:8.081e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 01:59 newton: it:2 norm:7.668e+00 upd:2.287e+00 rel_upd:2.983e-01 res:4.780e-03 red:1.703e-01 tot_red:8.655e-04
# 02:00 newton: it:3 norm:8.050e+00 upd:1.149e+00 rel_upd:1.427e-01 res:1.145e-03 red:2.395e-01 tot_red:2.072e-04
# 02:01 newton: it:4 norm:8.051e+00 upd:8.738e-02 rel_upd:1.085e-02 res:8.813e-06 red:7.700e-03 tot_red:1.596e-06
# 02:01 newton: it:5 norm:8.051e+00 upd:1.531e-03 rel_upd:1.901e-04 res:2.545e-09 red:2.887e-04 tot_red:4.608e-10
# 02:01 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#
# 02:01 newton:      norm:0.000e+00                                 res:5.523e+00
# 02:02 newton: it:1 norm:8.067e+00 upd:8.067e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 02:03 newton: it:2 norm:7.113e+00 upd:3.751e+00 rel_upd:5.273e-01 res:1.157e-02 red:4.122e-01 tot_red:2.095e-03
# 02:03 newton: it:3 norm:7.930e+00 upd:3.632e+00 rel_upd:4.580e-01 res:9.108e-03 red:7.872e-01 tot_red:1.649e-03
# 02:04 newton: it:4 norm:7.797e+00 upd:1.563e+00 rel_upd:2.004e-01 res:2.469e-03 red:2.710e-01 tot_red:4.470e-04
# 02:05 newton: it:5 norm:8.141e+00 upd:1.179e+00 rel_upd:1.448e-01 res:1.466e-03 red:5.940e-01 tot_red:2.655e-04
# 02:05 newton: it:6 norm:8.084e+00 upd:1.677e-01 rel_upd:2.075e-02 res:3.538e-05 red:2.412e-02 tot_red:6.405e-06
# 02:06 newton: it:7 norm:8.083e+00 upd:6.277e-03 rel_upd:7.766e-04 res:9.571e-08 red:2.705e-03 tot_red:1.733e-08
# 02:06 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#
# 02:06 newton:      norm:0.000e+00                                 res:5.523e+00
# 02:07 newton: it:1 norm:8.069e+00 upd:8.069e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 02:07 newton: it:2 norm:7.224e+00 upd:3.188e+00 rel_upd:4.413e-01 res:8.826e-03 red:3.144e-01 tot_red:1.598e-03
# 02:08 newton: it:3 norm:7.958e+00 upd:2.732e+00 rel_upd:3.434e-01 res:5.580e-03 red:6.322e-01 tot_red:1.010e-03
# 02:09 newton: it:4 norm:7.996e+00 upd:7.207e-01 rel_upd:9.013e-02 res:6.473e-04 red:1.160e-01 tot_red:1.172e-04
# 02:09 newton: it:5 norm:8.044e+00 upd:1.369e-01 rel_upd:1.702e-02 res:2.011e-05 red:3.106e-02 tot_red:3.640e-06
# 02:10 newton: it:6 norm:8.044e+00 upd:2.451e-03 rel_upd:3.047e-04 res:9.339e-09 red:4.645e-04 tot_red:1.691e-09
# 02:10 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#
# 02:10 newton:      norm:0.000e+00                                 res:5.523e+00
# 02:11 newton: it:1 norm:8.071e+00 upd:8.071e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 02:11 newton: it:2 norm:7.348e+00 upd:2.845e+00 rel_upd:3.871e-01 res:7.221e-03 red:2.572e-01 tot_red:1.308e-03
# 02:12 newton: it:3 norm:7.992e+00 upd:2.189e+00 rel_upd:2.740e-01 res:3.786e-03 red:5.244e-01 tot_red:6.856e-04
# 02:12 newton: it:4 norm:8.027e+00 upd:4.366e-01 rel_upd:5.439e-02 res:2.659e-04 red:7.023e-02 tot_red:4.815e-05
# 02:13 newton: it:5 norm:8.041e+00 upd:3.969e-02 rel_upd:4.936e-03 res:1.839e-06 red:6.914e-03 tot_red:3.329e-07
# 02:13 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#
# 02:13 newton:      norm:0.000e+00                                 res:5.523e+00
# 02:14 newton: it:1 norm:8.157e+00 upd:8.157e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 02:14 newton: it:2 norm:8.097e+00 upd:1.519e+00 rel_upd:1.876e-01 res:2.006e-03 red:7.147e-02 tot_red:3.633e-04
# 02:15 newton: it:3 norm:8.144e+00 upd:1.478e-01 rel_upd:1.814e-02 res:1.790e-05 red:8.924e-03 tot_red:3.242e-06
# 02:16 newton: it:4 norm:8.144e+00 upd:1.119e-03 rel_upd:1.374e-04 res:1.072e-09 red:5.985e-05 tot_red:1.940e-10
# 02:16 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#
# 02:16 newton:      norm:0.000e+00                                 res:5.523e+00
# 02:16 newton: it:1 norm:8.157e+00 upd:8.157e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 02:17 newton: it:2 norm:8.097e+00 upd:1.519e+00 rel_upd:1.876e-01 res:2.006e-03 red:7.146e-02 tot_red:3.632e-04
# 02:18 newton: it:3 norm:8.144e+00 upd:1.477e-01 rel_upd:1.814e-02 res:1.789e-05 red:8.917e-03 tot_red:3.239e-06
# 02:18 newton: it:4 norm:8.144e+00 upd:1.118e-03 rel_upd:1.372e-04 res:1.069e-09 red:5.979e-05 tot_red:1.936e-10
# 02:18 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#
# 02:18 newton:      norm:0.000e+00                                 res:5.523e+00
# 02:19 newton: it:1 norm:8.686e+00 upd:8.686e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 02:20 newton: it:2 norm:8.714e+00 upd:8.821e-01 rel_upd:1.012e-01 res:4.083e-04 red:1.455e-02 tot_red:7.393e-05
# 02:20 newton: it:3 norm:8.716e+00 upd:1.209e-02 rel_upd:1.387e-03 res:4.874e-08 red:1.194e-04 tot_red:8.826e-09
# 02:20 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#
# 02:20 newton:      norm:0.000e+00                                 res:5.523e+00
# 02:21 newton: it:1 norm:8.067e+00 upd:8.067e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 02:22 newton: it:2 norm:7.144e+00 upd:3.535e+00 rel_upd:4.948e-01 res:1.050e-02 red:3.741e-01 tot_red:1.901e-03
# 02:22 newton: it:3 norm:7.943e+00 upd:3.288e+00 rel_upd:4.139e-01 res:7.645e-03 red:7.280e-01 tot_red:1.384e-03
# 02:23 newton: it:4 norm:7.913e+00 upd:1.055e+00 rel_upd:1.334e-01 res:1.249e-03 red:1.634e-01 tot_red:2.262e-04
# 02:24 newton: it:5 norm:8.072e+00 upd:4.870e-01 rel_upd:6.034e-02 res:2.287e-04 red:1.831e-01 tot_red:4.142e-05
# 02:24 newton: it:6 norm:8.062e+00 upd:2.984e-02 rel_upd:3.701e-03 res:1.045e-06 red:4.569e-03 tot_red:1.892e-07
# 02:24 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#
# 02:24 newton:      norm:0.000e+00                                 res:5.523e+00
# 02:25 newton: it:1 norm:8.071e+00 upd:8.071e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 02:26 newton: it:2 norm:7.346e+00 upd:2.851e+00 rel_upd:3.881e-01 res:7.250e-03 red:2.583e-01 tot_red:1.313e-03
# 02:26 newton: it:3 norm:7.991e+00 upd:2.200e+00 rel_upd:2.753e-01 res:3.818e-03 red:5.266e-01 tot_red:6.913e-04
# 02:27 newton: it:4 norm:8.026e+00 upd:4.416e-01 rel_upd:5.502e-02 res:2.718e-04 red:7.119e-02 tot_red:4.921e-05
# 02:28 newton: it:5 norm:8.041e+00 upd:4.069e-02 rel_upd:5.060e-03 res:1.932e-06 red:7.109e-03 tot_red:3.499e-07
# 02:28 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#
# 02:28 newton:      norm:0.000e+00                                 res:5.523e+00
# 02:28 newton: it:1 norm:8.069e+00 upd:8.069e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 02:29 newton: it:2 norm:7.243e+00 upd:3.126e+00 rel_upd:4.316e-01 res:8.532e-03 red:3.039e-01 tot_red:1.545e-03
# 02:30 newton: it:3 norm:7.962e+00 upd:2.635e+00 rel_upd:3.309e-01 res:5.240e-03 red:6.142e-01 tot_red:9.489e-04
# 02:30 newton: it:4 norm:8.004e+00 upd:6.691e-01 rel_upd:8.359e-02 res:5.715e-04 red:1.090e-01 tot_red:1.035e-04
# 02:31 newton: it:5 norm:8.043e+00 upd:1.107e-01 rel_upd:1.376e-02 res:1.346e-05 red:2.356e-02 tot_red:2.438e-06
# 02:31 newton: it:6 norm:8.042e+00 upd:1.601e-03 rel_upd:1.990e-04 res:4.161e-09 red:3.091e-04 tot_red:7.535e-10
# 02:31 newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.

# %%
U.dim, len(U)
# Out:
# (1336, 10)

# %%
if 0: #assertion error
    dofs, cb, _ = ei_greedy(residuals, rtol=1e-7)
    ei_op = EmpiricalInterpolatedOperator(fom.operator, collateral_basis=cb, 
                                      interpolation_dofs=dofs, triangular=True) 
    
    rb, svals = pod(U, rtol=1e-7)
    fom_ei = fom.with_(operator=ei_op)
    reductor = StationaryRBReductor(fom_ei, rb)
    rom = reductor.reduce()
    # the reductor currently removes all solver_options so we need to add them again
    rom = rom.with_(operator=rom.operator.with_(solver_options=fom.operator.solver_options))
else:
    rb = gram_schmidt(U) # pod(U, rtol=1e-7)
    reductor = StationaryRBReductor(fom, rb)
    
    rom = reductor.reduce()
    # the reductor currently removes all solver_options so we need to add them again
    rom = rom.with_(operator=rom.operator.with_(solver_options=fom.operator.solver_options))
# Out:
# 03:27 gram_schmidt: Orthonormalizing vector 1 again
# 03:27 gram_schmidt: Orthonormalizing vector 2 again
# 03:27 gram_schmidt: Orthonormalizing vector 3 again
# 03:27 gram_schmidt: Orthonormalizing vector 4 again
# 03:27 gram_schmidt: Orthonormalizing vector 5 again
# 03:27 gram_schmidt: Orthonormalizing vector 6 again
# 03:27 gram_schmidt: Orthonormalizing vector 7 again
# 03:27 gram_schmidt: Orthonormalizing vector 8 again
# 03:27 gram_schmidt: Orthonormalizing vector 9 again
# 03:27 StationaryRBReductor: Operator projection ...
# 03:27 |   |WARNING|FenicsOperator: Using inefficient generic projection operator
# 03:27 StationaryRBReductor: Building ROM ...

# %%
rom.operator.solver_options
# Out:
# {'inverse': {'type': 'newton',
#   'rtol': 1e-06,
#   'maxiter': 500,
#   'error_measure': 'residual'}}

# %%
# ensure that FFC is not called during runtime measurements
rom.solve(1)
# Out:
# 03:34 |WARNING|FixedParameterOperator: Using inefficient generic projection operator
# 03:34 ProjectedOperator: Solving nonlinear problem using newton algorithm ...
# 03:34 |   newton:      norm:0.000e+00                                 res:4.264e+00
# 03:34 |   newton: it:1 norm:1.040e+01 upd:1.040e+01 rel_upd:1.000e+00 res:6.584e-03 red:1.544e-03 tot_red:1.544e-03
# 03:34 |   newton: it:2 norm:1.032e+01 upd:1.416e-01 rel_upd:1.373e-02 res:4.958e-08 red:7.530e-06 tot_red:1.163e-08
# 03:34 |   newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#       |
# NumpyVectorArray(
#     [[ 8.30009245e+00 -1.80174138e+00 -1.99364830e+00 -1.78152300e+00
#        4.18527067e+00  2.84590312e+00  1.22749697e+00  1.25897011e-02
#       -2.93612373e-03 -1.01668103e-02]],
#     NumpyVectorSpace(10))

# %% [markdown]
# ## ROM validation

# %%
import time

# %%
errs = []
speedups = []
for mu in parameter_space.sample_randomly(3):
    tic = time.perf_counter()
    U = fom.solve(mu)
    t_fom = time.perf_counter() - tic

    tic = time.perf_counter()
    u_red = rom.solve(mu)
    t_rom = time.perf_counter() - tic

    U_red = reductor.reconstruct(u_red)
    errs.append(((U - U_red).norm() / U.norm())[0])
    speedups.append(t_fom / t_rom)
print(f'Maximum relative ROM error: {max(errs)}')
print(f'Median of ROM speedup: {np.median(speedups)}')
# Out:
# 03:39 StationaryModel: Solving StationaryModel for {Re: [11.271662653605421]} ...
# 03:39 FenicsOperator: Solving nonlinear problem using newton algorithm ...
# 03:39 |   newton:      norm:0.000e+00                                 res:5.523e+00
# 03:40 |   newton: it:1 norm:1.178e+01 upd:1.178e+01 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 03:41 |   newton: it:2 norm:1.181e+01 upd:6.812e-01 rel_upd:5.770e-02 res:6.633e-05 red:2.363e-03 tot_red:1.201e-05
# 03:41 |   newton: it:3 norm:1.181e+01 upd:1.518e-03 rel_upd:1.286e-04 res:1.261e-10 red:1.901e-06 tot_red:2.283e-11
# 03:41 |   newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#       |
# 03:41 |WARNING|FixedParameterOperator: Using inefficient generic projection operator
# 03:41 ProjectedOperator: Solving nonlinear problem using newton algorithm ...
# 03:41 |   newton:      norm:0.000e+00                                 res:4.264e+00
# 03:41 |   newton: it:1 norm:1.042e+01 upd:1.042e+01 rel_upd:1.000e+00 res:6.587e-03 red:1.545e-03 tot_red:1.545e-03
# 03:41 |   newton: it:2 norm:9.562e+00 upd:1.494e+00 rel_upd:1.563e-01 res:5.955e-06 red:9.041e-04 tot_red:1.397e-06
# 03:41 |   newton: it:3 norm:9.562e+00 upd:1.111e-03 rel_upd:1.162e-04 res:4.702e-12 red:7.896e-07 tot_red:1.103e-12
# 03:41 |   newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#       |
# 03:41 StationaryModel: Solving StationaryModel for {Re: [484.98501622883515]} ...
# 03:41 FenicsOperator: Solving nonlinear problem using newton algorithm ...
# 03:41 |   newton:      norm:0.000e+00                                 res:5.523e+00
# 03:42 |   newton: it:1 norm:8.067e+00 upd:8.067e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 03:43 |   newton: it:2 norm:7.108e+00 upd:3.799e+00 rel_upd:5.345e-01 res:1.181e-02 red:4.209e-01 tot_red:2.139e-03
# 03:43 |   newton: it:3 norm:7.925e+00 upd:3.707e+00 rel_upd:4.677e-01 res:9.521e-03 red:8.059e-01 tot_red:1.724e-03
# 03:44 |   newton: it:4 norm:7.774e+00 upd:1.774e+00 rel_upd:2.283e-01 res:3.145e-03 red:3.303e-01 tot_red:5.695e-04
# 03:45 |   newton: it:5 norm:8.168e+00 upd:1.417e+00 rel_upd:1.735e-01 res:2.137e-03 red:6.796e-01 tot_red:3.870e-04
# 03:45 |   newton: it:6 norm:8.090e+00 upd:2.385e-01 rel_upd:2.948e-02 res:7.408e-05 red:3.466e-02 tot_red:1.341e-05
# 03:46 |   newton: it:7 norm:8.089e+00 upd:1.218e-02 rel_upd:1.506e-03 res:3.431e-07 red:4.632e-03 tot_red:6.213e-08
# 03:46 |   newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#       |
# 03:46 |WARNING|FixedParameterOperator: Using inefficient generic projection operator
# 03:46 ProjectedOperator: Solving nonlinear problem using newton algorithm ...
# 03:46 |   newton:      norm:0.000e+00                                 res:4.264e+00
# 03:46 |   newton: it:1 norm:1.120e+01 upd:1.120e+01 rel_upd:1.000e+00 res:6.369e-03 red:1.494e-03 tot_red:1.494e-03
# 03:46 |   newton: it:2 norm:1.360e+01 upd:4.233e+00 rel_upd:3.113e-01 res:7.752e-04 red:1.217e-01 tot_red:1.818e-04
# 03:46 |   newton: it:3 norm:8.060e+00 upd:1.076e+01 rel_upd:1.336e+00 res:4.643e-04 red:5.989e-01 tot_red:1.089e-04
# 03:46 |   newton: it:4 norm:8.088e+00 upd:2.373e-01 rel_upd:2.934e-02 res:8.791e-06 red:1.893e-02 tot_red:2.062e-06
# 03:46 |   newton: it:5 norm:8.089e+00 upd:1.991e-02 rel_upd:2.462e-03 res:7.878e-09 red:8.961e-04 tot_red:1.848e-09
# 03:46 |   newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#       |
# 03:46 StationaryModel: Solving StationaryModel for {Re: [416.38887775941043]} ...
# 03:46 FenicsOperator: Solving nonlinear problem using newton algorithm ...
# 03:46 |   newton:      norm:0.000e+00                                 res:5.523e+00
# 03:47 |   newton: it:1 norm:8.068e+00 upd:8.068e+00 rel_upd:1.000e+00 res:2.807e-02 red:5.083e-03 tot_red:5.083e-03
# 03:47 |   newton: it:2 norm:7.160e+00 upd:3.448e+00 rel_upd:4.815e-01 res:1.008e-02 red:3.590e-01 tot_red:1.825e-03
# 03:48 |   newton: it:3 norm:7.946e+00 upd:3.147e+00 rel_upd:3.961e-01 res:7.102e-03 red:7.048e-01 tot_red:1.286e-03
# 03:49 |   newton: it:4 norm:7.944e+00 upd:9.527e-01 rel_upd:1.199e-01 res:1.039e-03 red:1.462e-01 tot_red:1.880e-04
# 03:49 |   newton: it:5 norm:8.060e+00 upd:3.469e-01 rel_upd:4.304e-02 res:1.165e-04 red:1.122e-01 tot_red:2.110e-05
# 03:50 |   newton: it:6 norm:8.056e+00 upd:1.528e-02 rel_upd:1.896e-03 res:2.908e-07 red:2.496e-03 tot_red:5.266e-08
# 03:50 |   newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#       |
# 03:50 |WARNING|FixedParameterOperator: Using inefficient generic projection operator
# 03:50 ProjectedOperator: Solving nonlinear problem using newton algorithm ...
# 03:50 |   newton:      norm:0.000e+00                                 res:4.264e+00
# 03:50 |   newton: it:1 norm:1.108e+01 upd:1.108e+01 rel_upd:1.000e+00 res:6.399e-03 red:1.501e-03 tot_red:1.501e-03
# 03:50 |   newton: it:2 norm:1.309e+01 upd:3.832e+00 rel_upd:2.927e-01 res:7.995e-04 red:1.249e-01 tot_red:1.875e-04
# 03:50 |   newton: it:3 norm:8.046e+00 upd:1.009e+01 rel_upd:1.255e+00 res:3.630e-04 red:4.540e-01 tot_red:8.513e-05
# 03:50 |   newton: it:4 norm:8.056e+00 upd:2.018e-01 rel_upd:2.505e-02 res:4.290e-06 red:1.182e-02 tot_red:1.006e-06
# 03:50 |   newton: it:5 norm:8.056e+00 upd:1.206e-02 rel_upd:1.497e-03 res:1.293e-09 red:3.014e-04 tot_red:3.033e-10
# 03:50 |   newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#       |
# Maximum relative ROM error: 0.29651856407211324
# Median of ROM speedup: 52.847772102083226

# %%
def solve_rom_pymor(Re=1., rtol=1e-6, return_residuals=True):
    mu = rom.parameters.parse([Re])
    u_red = rom.solve(mu) 
    U_red = reductor.reconstruct(u_red)
    # fom solution
    U_fe = fenics.Function(W)
    U_fe.leaf_node().vector()[:] = U_red.to_numpy().squeeze()#.reshape((UU.to_numpy().size,))
    
    return U_fe

# %%
reynolds = 50.
U_py = solve_rom_pymor(Re=reynolds)
w = solve_fom_fenics(mu=reynolds)
# Out:
# 04:00 |WARNING|FixedParameterOperator: Using inefficient generic projection operator
# 04:00 ProjectedOperator: Solving nonlinear problem using newton algorithm ...
# 04:00 |   newton:      norm:0.000e+00                                 res:4.264e+00
# 04:00 |   newton: it:1 norm:1.049e+01 upd:1.049e+01 rel_upd:1.000e+00 res:6.568e-03 red:1.540e-03 tot_red:1.540e-03
# 04:00 |   newton: it:2 norm:8.332e+00 upd:4.647e+00 rel_upd:5.577e-01 res:1.185e-04 red:1.804e-02 tot_red:2.779e-05
# 04:00 |   newton: it:3 norm:8.326e+00 upd:4.027e-02 rel_upd:4.837e-03 res:4.754e-08 red:4.013e-04 tot_red:1.115e-08
# 04:00 |   newton: Relative tolerance of 1e-06 for norm of residual reached. Converged.
#       |
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.760e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 3.841e-09 (tol = 1.000e-10) r (rel) = 2.182e-06 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 8.188e-16 (tol = 1.000e-10) r (rel) = 4.652e-13 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.

# %%
# visualize reconstructed solution
plot_w(U_py)

# %%
# difference with fenics solution
diff = fenics.Function(W)
diff.leaf_node().vector()[:] = U_py.leaf_node().vector()[:] - w.leaf_node().vector()[:]
plot_w(diff)
